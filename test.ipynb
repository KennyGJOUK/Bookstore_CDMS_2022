# %%
import sqlalchemy
from sqlalchemy import Column, String, create_engine, Integer, Text, Date
from sqlalchemy.orm import sessionmaker,scoped_session
from sqlalchemy.ext.declarative import declarative_base
import time
from sqlalchemy import create_engine
engine = create_engine("postgresql://stu10194810401:Stu10194810401@dase-cdms-2022-pub.pg.rds.aliyuncs.com:5432/stu10194810401",
max_overflow=0,
# 链接池大小
pool_size=10,
# 链接池中没有可用链接则最多等待的秒数，超过该秒数后报错
pool_timeout=10,
# 多久之后对链接池中的链接进行一次回收
pool_recycle=1,
# 查看原生语句（未格式化）
echo=True
)

DbSession = sessionmaker(bind=engine)
session = DbSession()

# %%
session.rollback()
# Out:
# 2022-12-06 10:46:29,228 INFO sqlalchemy.engine.Engine ROLLBACK

# %%
cursor = session.execute(
    " select * from book as a inner join (select book_id from store where store_id = '%s') as c "
    " on a.book_id = c.book_id"
    " where to_tsvector('english', book_intro) "
    " @@ to_tsquery('english','%s')"
    " limit %d offset %d"%('test_deliver_book_store_id_038b8580-75fc-11ed-8429-bc6ee2c8884f',
    '体',10,(1-1)*10)
)
cursor.fetchall()
# Out:
# 2022-12-07 15:56:25,228 INFO sqlalchemy.engine.Engine  select * from book as a inner join (select book_id from store where store_id = 'test_deliver_book_store_id_038b8580-75fc-11ed-8429-bc6ee2c8884f') as c  on a.book_id = c.book_id where to_tsvector('english', book_intro)  @@ to_tsquery('english','体') limit 10 offset 0
# 2022-12-07 15:56:25,229 INFO sqlalchemy.engine.Engine [generated in 0.00086s] {}
# []

# %%
session.execute("select book_id from store").fetchall()
# Out:
# 2022-12-07 15:54:10,074 INFO sqlalchemy.engine.Engine select * from store
# 2022-12-07 15:54:10,075 INFO sqlalchemy.engine.Engine [generated in 0.00077s] {}
# [('王掌柜的书店', '1', None, 10),
#  ('王掌柜的进口书店', '2', None, 10),
#  ('test_deliver_book_store_id_038b8580-75fc-11ed-8429-bc6ee2c8884f', '1000167', '{"tags": ["\\u5de5\\u5177\\u4e66", "\\u5386\\u53f2", "\\u674e\\u5d07\\u667a", "\\u4e2d\\u570b\\u6b77\\u4ee3\\u5e74\\u865f\\u8003", "\\u5e74\\u865f",  ... (254153 characters truncated) ... c\\u5317\\u5143\\uff09\\n\\u660e\\uff08\\u5305\\u62ec\\u5357\\u660e\\uff09\\n\\u6e05\\n\\u00b7 \\u00b7 \\u00b7 \\u00b7 \\u00b7 \\u00b7     (\\n)\\n"}', 23),
# ...

# %%
# a = a[0]
import jieba 
ret = list(jieba.cut(a, cut_all= True))
stop_word = ['', '\n', '、','（','）','，',' ','(',')','.','·']
ret = list(filter(lambda x:x not in stop_word,ret))
ret
# Out:
# ['凡例',
#  '酉',
#  '汉',
#  '包括',
#  '新莽',
#  '更始',
#  '等',
#  '东汉',
#  '三国',
#  '魏',
#  '蜀',
#  '昊',
#  '晋',
#  '及',
#  '十六',
#  '六国',
#  '西晋',
#  '东晋',
#  '前',
#  '赵',
#  '成汉',
#  '前',
#  '凉',
#  '後',
#  '赵',
#  '包括',
#  '冉魏',
#  '前',
#  '燕',
#  '前秦',
#  '後',
#  '秦',
#  '後',
#  '燕',
#  '西燕',
#  '西秦',
#  '後',
#  '凉',
#  '南凉',
#  '南燕',
#  '西凉',
#  '夏',
#  '北燕',
#  '北凉',
#  '南北',
#  '南北朝',
#  '北朝',
#  '宋',
#  '齐',
#  '梁',
#  '包括',
#  '後',
#  '梁',
#  '陈',
#  '北魏',
#  '东魏',
#  '西魏',
#  '北齐',
#  '北周',
#  '柔然',
#  '高',
#  '昌',
#  '隋',
#  '唐',
#  '吐蕃',
#  '于',
#  '阗',
#  '渤海',
#  '海东',
#  '东丹',
#  '定安',
#  '南诏',
#  '大理',
#  '五代',
#  '五代十国',
#  '十国',
#  '後',
#  '梁',
#  '後',
#  '店',
#  '後',
#  '晋',
#  '後',
#  '汉',
#  '後',
#  '周',
#  '昊',
#  '南唐',
#  '昊',
#  '越',
#  '楚',
#  '闽',
#  '南汉',
#  '前',
#  '蜀',
#  '後',
#  '蜀',
#  '荆南',
#  '南平',
#  '北汉',
#  '北宋',
#  '南宋',
#  '辽',
#  '包括',
#  '北',
#  '辽',
#  '西辽',
#  '西夏',
#  '金',
#  '兀',
#  '包括',
#  '北',
#  '元',
#  '明',
#  '包括',
#  '南明',
#  '清']

# %%
json = {
            "user_id": 'test_add_books_store_id_cae12118-738a-11ed-aa42-8038fb8a6bd1',
            "stype": 'invert_tag',
            'svalue': '历史',
            'page': 1
        }

import requests
ret = requests.post("http://127.0.0.1:5000/buyer/search_store",
    json=json
)
print(ret)
# Out:
# <Response [500]>

# %%
json = {
            "user_id": '小明',
            "stype": 'invert_tag',
            'svalue': '历史',
            'page': 1
        }

import requests
ret = requests.post("http://127.0.0.1:5000/buyer/search_global",
    json=json
)
print(ret)
# Out:
# <Response [200]>

# %%
ret = session.execute("select title from book where title != '' limit 10;").fetchall()
ret
# Out:
# 2022-12-05 22:22:49,315 INFO sqlalchemy.engine.Engine select title from book where title != '' limit 10;
# 2022-12-05 22:22:49,316 INFO sqlalchemy.engine.Engine [generated in 0.00113s] {}
# [('美丽心灵',),
#  ('三毛流浪记全集',),
#  ('黑色棉花田',),
#  ('中国历代年号考',),
#  ('袁氏当国',),
#  ('一个狗娘养的自白',),
#  ('新唐书（全二十册）',),
#  ('第二次世界大战回忆录（全六卷）',),
#  ('学习的革命',),
#  ('人类本性与社会秩序',)]

# %%
from fe.access.book import BookDB
db = BookDB()
## get total size
size = db.get_book_count()
## get local book data from sqlite
data = db.get_book_info(0, size)
a = 'pictures'
(''.join(eval('list(data)[0].'+a))).encode('utf-8')
# Out:
# b'...'
