# %%
import sqlalchemy
from sqlalchemy import Column, String, create_engine, Integer, Text, Date
from sqlalchemy.orm import sessionmaker,scoped_session
from sqlalchemy.ext.declarative import declarative_base
import time
from sqlalchemy import create_engine
engine = create_engine("postgresql://stu10194810401:Stu10194810401@dase-cdms-2022-pub.pg.rds.aliyuncs.com:5432/stu10194810401",
max_overflow=0,
# 链接池大小
pool_size=10,
# 链接池中没有可用链接则最多等待的秒数，超过该秒数后报错
pool_timeout=10,
# 多久之后对链接池中的链接进行一次回收
pool_recycle=1,
# 查看原生语句（未格式化）
echo=True
)

DbSession = sessionmaker(bind=engine)
session = DbSession()

# %%
session.rollback()
# Out:
# 2022-12-06 10:46:29,228 INFO sqlalchemy.engine.Engine ROLLBACK

# %%
ret = session.execute("selectbook_id, tags from book limit 10;").fetchall()
ret
# Out:
# 2022-12-06 10:48:21,967 INFO sqlalchemy.engine.Engine selectbook_id, tags from book limit 10;
# 2022-12-06 10:48:21,968 INFO sqlalchemy.engine.Engine [generated in 0.00094s] {}
# ---------------------------------------------------------------------------
# SyntaxError                               Traceback (most recent call last)
# d:\software\anaconda\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1704                 if not evt_handled:
# -> 1705                     self.dialect.do_execute(
#    1706                         cursor, statement, parameters, context
#
# d:\software\anaconda\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     691     def do_execute(self, cursor, statement, parameters, context=None):
# --> 692         cursor.execute(statement, parameters)
#     693
#
# SyntaxError: syntax error at or near "selectbook_id"
# LINE 1: selectbook_id, tags from book limit 10;
#         ^
#
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-70-a5e5cdcf4e49> in <module>
# ----> 1 ret = session.execute("selectbook_id, tags from book limit 10;").fetchall()
#       2 ret
#
# d:\software\anaconda\lib\site-packages\sqlalchemy\orm\session.py in execute(self, statement, params, execution_options, bind_arguments, _parent_execute_state, _add_event, **kw)
#    1668
#    1669         conn = self._connection_for_bind(bind, close_with_result=True)
# -> 1670         result = conn._execute_20(statement, params or {}, execution_options)
#    1671
#    1672         if compile_state_cls:
#
# d:\software\anaconda\lib\site-packages\sqlalchemy\engine\base.py in _execute_20(self, statement, parameters, execution_options)
#    1518             )
#    1519         else:
# -> 1520             return meth(self, args_10style, kwargs_10style, execution_options)
#    1521
#    1522     def exec_driver_sql(
#
# d:\software\anaconda\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params, execution_options, _force)
#     311     ):
#     312         if _force or self.supports_execution:
# --> 313             return connection._execute_clauseelement(
#     314                 self, multiparams, params, execution_options
#     315             )
#
# d:\software\anaconda\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params, execution_options)
#    1387             linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1388         )
# -> 1389         ret = self._execute_context(
#    1390             dialect,
#    1391             dialect.execution_ctx_cls._init_compiled,
#
# d:\software\anaconda\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1746
#    1747         except BaseException as e:
# -> 1748             self._handle_dbapi_exception(
#    1749                 e, statement, parameters, cursor, context
#    1750             )
#
# d:\software\anaconda\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1927                 util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    1928             elif should_wrap:
# -> 1929                 util.raise_(
#    1930                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1931                 )
#
# d:\software\anaconda\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# d:\software\anaconda\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1703                             break
#    1704                 if not evt_handled:
# -> 1705                     self.dialect.do_execute(
#    1706                         cursor, statement, parameters, context
#    1707                     )
#
# d:\software\anaconda\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     690
#     691     def do_execute(self, cursor, statement, parameters, context=None):
# --> 692         cursor.execute(statement, parameters)
#     693
#     694     def do_execute_no_params(self, cursor, statement, context=None):
#
# ProgrammingError: (psycopg2.errors.SyntaxError) syntax error at or near "selectbook_id"
# LINE 1: selectbook_id, tags from book limit 10;
#         ^
#
# [SQL: selectbook_id, tags from book limit 10;]
# (Background on this error at: http://sqlalche.me/e/14/f405)

# %%
# a = a[0]
import jieba 
ret = list(jieba.cut(a, cut_all= True))
stop_word = ['', '\n', '、','（','）','，',' ','(',')','.','·']
ret = list(filter(lambda x:x not in stop_word,ret))
ret
# Out:
# ['凡例',
#  '酉',
#  '汉',
#  '包括',
#  '新莽',
#  '更始',
#  '等',
#  '东汉',
#  '三国',
#  '魏',
#  '蜀',
#  '昊',
#  '晋',
#  '及',
#  '十六',
#  '六国',
#  '西晋',
#  '东晋',
#  '前',
#  '赵',
#  '成汉',
#  '前',
#  '凉',
#  '後',
#  '赵',
#  '包括',
#  '冉魏',
#  '前',
#  '燕',
#  '前秦',
#  '後',
#  '秦',
#  '後',
#  '燕',
#  '西燕',
#  '西秦',
#  '後',
#  '凉',
#  '南凉',
#  '南燕',
#  '西凉',
#  '夏',
#  '北燕',
#  '北凉',
#  '南北',
#  '南北朝',
#  '北朝',
#  '宋',
#  '齐',
#  '梁',
#  '包括',
#  '後',
#  '梁',
#  '陈',
#  '北魏',
#  '东魏',
#  '西魏',
#  '北齐',
#  '北周',
#  '柔然',
#  '高',
#  '昌',
#  '隋',
#  '唐',
#  '吐蕃',
#  '于',
#  '阗',
#  '渤海',
#  '海东',
#  '东丹',
#  '定安',
#  '南诏',
#  '大理',
#  '五代',
#  '五代十国',
#  '十国',
#  '後',
#  '梁',
#  '後',
#  '店',
#  '後',
#  '晋',
#  '後',
#  '汉',
#  '後',
#  '周',
#  '昊',
#  '南唐',
#  '昊',
#  '越',
#  '楚',
#  '闽',
#  '南汉',
#  '前',
#  '蜀',
#  '後',
#  '蜀',
#  '荆南',
#  '南平',
#  '北汉',
#  '北宋',
#  '南宋',
#  '辽',
#  '包括',
#  '北',
#  '辽',
#  '西辽',
#  '西夏',
#  '金',
#  '兀',
#  '包括',
#  '北',
#  '元',
#  '明',
#  '包括',
#  '南明',
#  '清']

# %%
json = {
            "user_id": 'test_add_books_store_id_cae12118-738a-11ed-aa42-8038fb8a6bd1',
            "stype": 'invert_tag',
            'svalue': '历史',
            'page': 1
        }

import requests
ret = requests.post("http://127.0.0.1:5000/buyer/search_store",
    json=json
)
print(ret)
# Out:
# <Response [500]>

# %%
json = {
            "user_id": '小明',
            "stype": 'invert_tag',
            'svalue': '历史',
            'page': 1
        }

import requests
ret = requests.post("http://127.0.0.1:5000/buyer/search_global",
    json=json
)
print(ret)
# Out:
# <Response [200]>

# %%
ret = session.execute("select title from book where title != '' limit 10;").fetchall()
ret
# Out:
# 2022-12-05 22:22:49,315 INFO sqlalchemy.engine.Engine select title from book where title != '' limit 10;
# 2022-12-05 22:22:49,316 INFO sqlalchemy.engine.Engine [generated in 0.00113s] {}
# [('美丽心灵',),
#  ('三毛流浪记全集',),
#  ('黑色棉花田',),
#  ('中国历代年号考',),
#  ('袁氏当国',),
#  ('一个狗娘养的自白',),
#  ('新唐书（全二十册）',),
#  ('第二次世界大战回忆录（全六卷）',),
#  ('学习的革命',),
#  ('人类本性与社会秩序',)]

# %%
from fe.access.book import BookDB
db = BookDB()
## get total size
size = db.get_book_count()
## get local book data from sqlite
data = db.get_book_info(0, size)
a = 'pictures'
(''.join(eval('list(data)[0].'+a))).encode('utf-8')
# Out:
# b'...'
